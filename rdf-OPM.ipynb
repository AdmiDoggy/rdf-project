# %% [markdown]
# # ONE PUNCH MAN

# %%
# !pip install rdflib

# %%
from rdflib import URIRef, BNode, Literal, Graph
from rdflib import Namespace
from rdflib.namespace import RDF, RDFS

# %% [markdown]
# # Modelado del Grafo

# %% [markdown]
# Ingresando URIs de los sujetos

# %%
#####Heroes
###Asociación de Héroes
##Clase S
blast = URIRef('https://onepunchman.fandom.com/es/wiki/Blast')
tatsumaki = URIRef('https://onepunchman.fandom.com/es/wiki/Tatsumaki')
bang = URIRef('https://onepunchman.fandom.com/es/wiki/Bang')
kamikaze = URIRef('https://onepunchman.fandom.com/es/wiki/Kamikaze')
kidEmperor = URIRef('https://onepunchman.fandom.com/es/wiki/Kid_Emperor')
metalKnight = URIRef('https://onepunchman.fandom.com/es/wiki/Bofoi')
king = URIRef('https://onepunchman.fandom.com/es/wiki/King')
zombieman = URIRef('https://onepunchman.fandom.com/es/wiki/Zombieman')
driveKnight = URIRef('https://onepunchman.fandom.com/es/wiki/Drive_Knight')
pigGod = URIRef('https://onepunchman.fandom.com/es/wiki/Pig_God')
darkshine = URIRef('https://onepunchman.fandom.com/es/wiki/Superalloy_Darkshine')
watchdog = URIRef('https://onepunchman.fandom.com/es/wiki/Watchdog_Man')
flashy = URIRef('https://onepunchman.fandom.com/es/wiki/Flashy_Flash')
genos = URIRef('https://onepunchman.fandom.com/es/wiki/Genos')
bad = URIRef('https://onepunchman.fandom.com/es/wiki/Bad')
tanktop = URIRef('https://onepunchman.fandom.com/es/wiki/Tanktop_Master')
lindolindo = URIRef('https://onepunchman.fandom.com/es/wiki/Prisionero_Lindo-Lindo')

##Clase A
amai = URIRef('https://onepunchman.fandom.com/es/wiki/Amai_Mask')
iaian = URIRef('https://onepunchman.fandom.com/es/wiki/Iaian')
okamaitachi = URIRef('https://onepunchman.fandom.com/es/wiki/Okamaitachi')
bushidrill = URIRef('https://onepunchman.fandom.com/es/wiki/Bushidrill')
fundoshi = URIRef('https://onepunchman.fandom.com/es/wiki/Heavy_Tank_Fundoshi')
blueFire = URIRef('https://onepunchman.fandom.com/es/wiki/Blue_Fire')
gatling = URIRef('https://onepunchman.fandom.com/es/wiki/Death_Gatling')
stinger = URIRef('https://onepunchman.fandom.com/es/wiki/Stinger')
twinTail = URIRef('https://onepunchman.fandom.com/es/wiki/Twin_Tail')
filosofo = URIRef('https://onepunchman.fandom.com/es/wiki/Gran_Filósofo')
butterfly = URIRef('https://onepunchman.fandom.com/es/wiki/Butterfly_DX')
genji = URIRef('https://onepunchman.fandom.com/es/wiki/Genji')
maxx = URIRef('https://onepunchman.fandom.com/es/wiki/Max')
oneShooter = URIRef('https://onepunchman.fandom.com/es/wiki/One_Shooter')
green = URIRef('https://onepunchman.fandom.com/es/wiki/Green')
eyebroll = URIRef('https://onepunchman.fandom.com/es/wiki/Crescent_Eyebroll')

##Clase B
fubuki = URIRef('https://onepunchman.fandom.com/es/wiki/Fubuki')
pestañas = URIRef('https://onepunchman.fandom.com/es/wiki/Pestañas')
mono = URIRef('https://onepunchman.fandom.com/es/wiki/Mono_de_Montaña')
saitama = URIRef('https://onepunchman.fandom.com/es/wiki/Saitama')
wildHorn = URIRef('https://onepunchman.fandom.com/es/wiki/Wild_Horn')
gafas = URIRef('https://onepunchman.fandom.com/es/wiki/Gafas')
avispon = URIRef('https://onepunchman.fandom.com/es/wiki/Avispón_Rosa')
smellMaster = URIRef('https://onepunchman.fandom.com/es/wiki/Smell_Master')
reclusamurai = URIRef('https://onepunchman.fandom.com/es/wiki/Reclusamurai')
gungun = URIRef('https://onepunchman.fandom.com/es/wiki/Gun_Gun')
carnicero = URIRef('https://onepunchman.fandom.com/es/wiki/Carnicero')
niceGuy = URIRef('https://onepunchman.fandom.com/es/wiki/Jet_Nice_Guy')
cuchillaOscura = URIRef('https://onepunchman.fandom.com/es/wiki/Cuchilla_Oscura')
needleStar = URIRef('https://onepunchman.fandom.com/es/wiki/Needle_Star')
piko = URIRef('https://onepunchman.fandom.com/es/wiki/Piko')

##Clase C
satoru = URIRef('https://onepunchman.fandom.com/es/wiki/Satoru')
biningShell = URIRef('https://onepunchman.fandom.com/es/wiki/Strange_Binding_Shell')
tiger = URIRef('https://onepunchman.fandom.com/es/wiki/Tanktop_Tiger')
dPad = URIRef('https://onepunchman.fandom.com/es/wiki/D-Pad')
tirantes = URIRef('https://onepunchman.fandom.com/es/wiki/Tirantes_Fúnebres')
luchadorComida = URIRef('https://onepunchman.fandom.com/es/wiki/Luchador_de_Comida_Futoshi')
hombreBateria = URIRef('https://onepunchman.fandom.com/es/wiki/Hombre_Batería')
redMuffler = URIRef('https://onepunchman.fandom.com/es/wiki/Red_Muffler')
recepcionista = URIRef('https://onepunchman.fandom.com/es/wiki/Recepcionista_Blindado')
gearsper = URIRef('https://onepunchman.fandom.com/es/wiki/Gearsper')
vaquero = URIRef('https://onepunchman.fandom.com/es/wiki/Vaquero_con_Máscara_de_Gas')
octavaTumba = URIRef('https://onepunchman.fandom.com/es/wiki/Octava_Tumba')
ecoloG = URIRef('https://onepunchman.fandom.com/es/wiki/Ecolo_G')
monocross = URIRef('https://onepunchman.fandom.com/es/wiki/Monocross')
hombreDinamita = URIRef('https://onepunchman.fandom.com/es/wiki/Hombre_Dinamita')

# %%
n = Namespace('https://onepunchman.fandom.com/')

# %%
####Caracteristicas

name = URIRef('characteristics/name')
rank = URIRef('characteristics/rank')
edad = URIRef('characteristics/age')
alias = URIRef('characteristics/alias')

# %%
#### Personal de la Asociación de Héroes
agoni = URIRef('https://onepunchman.fandom.com/es/wiki/Agoni')
trabajadorBarbado = URIRef('https://onepunchman.fandom.com/es/wiki/Trabajador_Barbado')
trabajadorConGafas = URIRef('https://onepunchman.fandom.com/es/wiki/Trabajador_con_Gafas')
operadoraRamaC = URIRef('https://onepunchman.fandom.com/es/wiki/Operadora_de_la_Rama_C')
trabajadorRamaC = URIRef('https://onepunchman.fandom.com/es/wiki/Trabajador_de_la_Rama_C')
operadoraDeConsola = URIRef('https://onepunchman.fandom.com/es/wiki/Operadora_de_Consola')
guiches = URIRef('https://onepunchman.fandom.com/es/wiki/Guiches')
operadoraRamaPrincipal = URIRef('https://onepunchman.fandom.com/es/wiki/Operadora_de_la_Rama_Principal')
mcCoy = URIRef('https://onepunchman.fandom.com/es/wiki/McCoy')
narinko = URIRef('https://onepunchman.fandom.com/es/wiki/Narinki')
sekingar = URIRef('https://onepunchman.fandom.com/es/wiki/Sekingar')
chicaRefugioSiete = URIRef('https://onepunchman.fandom.com/es/wiki/Chica_del_Refugio_N%C2%BA7')
sitch = URIRef('https://onepunchman.fandom.com/es/wiki/Sitch')
zeimeet = URIRef('https://onepunchman.fandom.com/es/wiki/Zeimeet')
operadoraRamaZ = URIRef('https://onepunchman.fandom.com/es/wiki/Operadora_de_la_Rama_Z')
chicaComiteRamaZ = URIRef('https://onepunchman.fandom.com/es/wiki/Chica_del_comit%C3%A9_de_la_Rama_Z')
chicaComiteEspecial = URIRef('https://onepunchman.fandom.com/es/wiki/Chica_del_comit%C3%A9_especial')

# %%
###Clase Desconocida

tanktopRockabilly = URIRef('https://onepunchman.fandom.com/es/wiki/Tanktop_Rockabilly')
tanktopGirl = URIRef('https://onepunchman.fandom.com/es/wiki/Tanktop_Girl')
tanktopRacer = URIRef('https://onepunchman.fandom.com/es/wiki/Tanktop_Racer')
tanktopHatter = URIRef('https://onepunchman.fandom.com/es/wiki/Tanktop_Hatter')
tanktopJungle = URIRef('https://onepunchman.fandom.com/es/wiki/Tanktop_Jungle')
tanktopSwimmer = URIRef('https://onepunchman.fandom.com/es/wiki/Tanktop_Swimmer')
tanktopMask = URIRef('https://onepunchman.fandom.com/es/wiki/Tanktop_Mask')
pandaman = URIRef('https://onepunchman.fandom.com/es/wiki/Pandaman')

#### Ex Heroes conocidos
allBackMan = URIRef('https://onepunchman.fandom.com/es/wiki/All_Back-Man')
serialBomber = URIRef('https://onepunchman.fandom.com/es/wiki/Serial_Bomber')
graduadoDePostgrado = URIRef('https://onepunchman.fandom.com/es/wiki/Graduado_de_Posgrado')
tanktopVegetarian = URIRef('https://onepunchman.fandom.com/es/wiki/Tanktop_Vegetarian')

# %%
#####Asociación de Monstruos

##Superiores

#Líderes
Psykos = URIRef('https://onepunchman.fandom.com/es/wiki/Psykos')
Orochi = URIRef('https://onepunchman.fandom.com/es/wiki/Orochi')

#Ejecutivos
AguaNaturalMalvada = URIRef('https://onepunchman.fandom.com/es/wiki/Agua_Natural_Malvada')
BlackSperm = URIRef('https://onepunchman.fandom.com/es/wiki/Black_Sperm')
CiempiésAnciano = URIRef('https://onepunchman.fandom.com/es/wiki/Ciempiés_Anciano')
EmperadorsinHogar = URIRef('https://onepunchman.fandom.com/es/wiki/Emperador_sin_Hogar')
Encias = URIRef('https://onepunchman.fandom.com/es/wiki/Encias')
FuhrerUgly = URIRef('https://onepunchman.fandom.com/es/wiki/Fuhrer_Ugly')
ouketsu = URIRef('https://onepunchman.fandom.com/es/wiki/Gouketsu')
Nyan = URIRef('https://onepunchman.fandom.com/es/wiki/Nyan')
OvergrownRover = URIRef('https://onepunchman.fandom.com/es/wiki/Overgrown_Rover')


##Subordinados

#Nivel Dragon
Bakuzan = URIRef('https://onepunchman.fandom.com/es/wiki/Bakuzan')
GaleWind = URIRef('https://onepunchman.fandom.com/es/wiki/Gale_Wind')
HellfireFlame = URIRef('https://onepunchman.fandom.com/es/wiki/Hellfire_Flame')
PhoenixMan = URIRef('https://onepunchman.fandom.com/es/wiki/Phoenix_Man')

#Nivel Ogro
AbrazadorGratuito = URIRef('https://onepunchman.fandom.com/es/wiki/Abrazador_Gratuito')
Bakuma = URIRef('https://onepunchman.fandom.com/es/wiki/Bakuma')
DiosInsecto = URIRef('https://onepunchman.fandom.com/es/wiki/Dios_Insecto')
CabelloLargoDemoniaco = URIRef('https://onepunchman.fandom.com/es/wiki/Cabello_Largo_Demoniaco')
CiempiésMayor = URIRef('https://onepunchman.fandom.com/es/wiki/Ciempiés_Mayor')
CucarachaAvispada = URIRef('https://onepunchman.fandom.com/es/wiki/Cucaracha_Avispada')
DoS = URIRef('https://onepunchman.fandom.com/es/wiki/Do-S')
yesight = URIRef('https://onepunchman.fandom.com/es/wiki/Eyesight')
FistFightDjinn = URIRef('https://onepunchman.fandom.com/es/wiki/Fist_Fight_Djinn')
G5 = URIRef('https://onepunchman.fandom.com/es/wiki/G5')
G4 = URIRef('https://onepunchman.fandom.com/es/wiki/G4')
heGreatFoodTub = URIRef('https://onepunchman.fandom.com/es/wiki/The_Great_Food_Tub')
PulpoDeCienOjos = URIRef('https://onepunchman.fandom.com/es/wiki/Pulpo_de_Cien_Ojos')
Rafflesidon = URIRef('https://onepunchman.fandom.com/es/wiki/Rafflesidon')
RhinoWrestler= URIRef('https://onepunchman.fandom.com/es/wiki/Rhino_Wrestler')
RoyalRipper = URIRef('https://onepunchman.fandom.com/es/wiki/Royal_Ripper')
SangrePura = URIRef('https://onepunchman.fandom.com/es/wiki/Sangre_Pura')
SegadorDeRostros = URIRef('https://onepunchman.fandom.com/es/wiki/Segador_de_Rostros')
Showerhead= URIRef('https://onepunchman.fandom.com/es/wiki/Showerhead')
SuperRatón = URIRef('https://onepunchman.fandom.com/es/wiki/Super_Ratón')
LosTresCuervos = URIRef('https://onepunchman.fandom.com/es/wiki/Los_Tres_Cuervos')
Unicuerno = URIRef('https://onepunchman.fandom.com/es/wiki/Unicuerno')

#Nivel Tigre
Destrochloridium = URIRef('https://onepunchman.fandom.com/es/wiki/Destrochloridium')
ElectricCatfishMan = URIRef('https://onepunchman.fandom.com/es/wiki/Electric_Catfish_Man')
GorilaMarshall = URIRef('https://onepunchman.fandom.com/es/wiki/Gorila_Marshall')
MadDoctorFish = URIRef('https://onepunchman.fandom.com/es/wiki/Mad_Doctor_Fish')
MaikoPlasma = URIRef('https://onepunchman.fandom.com/es/wiki/Maiko_Plasma')
SludgeJellyfish = URIRef('https://onepunchman.fandom.com/es/wiki/Sludge_Jellyfish')

# %%
#### Aliens ( ladrones de materia oscura)

##Líder
boros = URIRef('https://onepunchman.fandom.com/es/wiki/Boros')

##Fuerza Élite
geryuganshoop = URIRef('https://onepunchman.fandom.com/es/wiki/Geryuganshoop')
melzargard = URIRef('https://onepunchman.fandom.com/es/wiki/Melzargard')
groribas = URIRef('https://onepunchman.fandom.com/es/wiki/Groribas')

# %%
#### Casa de la evolución

asuraKabuto = URIRef('https://onepunchman.fandom.com/es/wiki/Asura_Kabuto')
beastKing = URIRef('https://onepunchman.fandom.com/es/wiki/Beast_King')
gorilaBlindado = URIRef('https://onepunchman.fandom.com/es/wiki/Gorila_Blindado')
chicaMosquito= URIRef('https://onepunchman.fandom.com/es/wiki/Chica_Mosquito')
mantis = URIRef('https://onepunchman.fandom.com/es/wiki/Mantis')
groundDragon = URIRef('https://onepunchman.fandom.com/es/wiki/Ground_Dragon')
slugerous = URIRef('https://onepunchman.fandom.com/es/wiki/Slugerous')
rana = URIRef('https://onepunchman.fandom.com/es/wiki/Hombre_Rana')

# %%
#### Habitantes de las profundidades

underlordDream = URIRef('https://onepunchman.fandom.com/es/wiki/Underlord')
underlord = URIRef('https://onepunchman.fandom.com/es/wiki/Underlord')
habitantesDeLasProfundidades = URIRef('https://onepunchman.fandom.com/es/wiki/Habitantes_de_las_Profundidades')

# %%
#### Seafolk

reyDelMarProfundo = URIRef('https://onepunchman.fandom.com/es/wiki/Rey_del_Mar_Profundo')
mensajeroSeafolk = URIRef('https://onepunchman.fandom.com/es/wiki/Mensajero_Seafolk')
lordGranBlanco = URIRef('https://onepunchman.fandom.com/es/wiki/Lord_Gran_Blanco')
marinos = URIRef('https://onepunchman.fandom.com/es/wiki/Seafolk')
anguilaDeUrna = URIRef('https://onepunchman.fandom.com/es/wiki/Anguila_de_urna')

#### Skyfolk

skyKing = URIRef('https://onepunchman.fandom.com/es/wiki/Sky_King')
aguila = URIRef('https://onepunchman.fandom.com/es/wiki/%C3%81guila')
halcon = URIRef('https://onepunchman.fandom.com/es/wiki/Halc%C3%B3n')
gavilan = URIRef('https://onepunchman.fandom.com/es/wiki/Gavil%C3%A1n')
cometa = URIRef('https://onepunchman.fandom.com/es/wiki/Cometa')

#### Dinofolk

reyAntiguo = URIRef('https://onepunchman.fandom.com/es/wiki/Rey_Antiguo')

# %%
#### Monstruos Sin Afiliacion

kanirante = URIRef('https://onepunchman.fandom.com/es/wiki/Kanirante')
vaccineMan = URIRef('https://onepunchman.fandom.com/es/wiki/Vaccine_Man')
marugori = URIRef('https://onepunchman.fandom.com/es/wiki/Marugori')
bariCustom = URIRef('https://onepunchman.fandom.com/es/wiki/BariCustom_YO649Z_Mk._II')
kombuInfinito= URIRef('https://onepunchman.fandom.com/es/wiki/Kombu_Infinito')
gusanoDeTierra = URIRef('https://onepunchman.fandom.com/es/wiki/Gusano_de_Tierra')
crazyBrownBear = URIRef('https://onepunchman.fandom.com/es/wiki/Crazy_Brown_Bear')
lordOfMountains = URIRef('https://onepunchman.fandom.com/es/wiki/Lord_of_Mountains')
larvaMagiciada = URIRef('https://onepunchman.fandom.com/es/wiki/Larva_Magiciada_de_170_000-A%C3%B1os')
cigarraAdulta = URIRef('https://onepunchman.fandom.com/es/wiki/Cigarra_Adulta_de_170_000-A%C3%B1os')
demonioVentilador = URIRef('https://onepunchman.fandom.com/es/wiki/Demonio_Ventilador')
piggyBacon = URIRef('https://onepunchman.fandom.com/es/wiki/Piggy_Bancon')
encarnacionDelCordonDelCableDeLuz= URIRef('https://onepunchman.fandom.com/es/wiki/Encarnaci%C3%B3n_del_Cord%C3%B3n_del_cable_de_Luz')
surpriseAttackPlum = URIRef('https://onepunchman.fandom.com/es/wiki/Surprise-Attack_Plum')
grizzlyNyah = URIRef('https://onepunchman.fandom.com/es/wiki/Grizzly_Nyah')
gameBerus = URIRef('https://onepunchman.fandom.com/es/wiki/Game-Berus')
octopusClawMan = URIRef('https://onepunchman.fandom.com/es/wiki/Octopus_Claw_Man')
suppon = URIRef('https://onepunchman.fandom.com/es/wiki/Suppon')
cuervoGigante = URIRef('https://onepunchman.fandom.com/es/wiki/Cuervo_Gigante')
tongueStretcher= URIRef('https://onepunchman.fandom.com/es/wiki/Tongue_Stretcher')
aranhaSaltarina = URIRef('https://onepunchman.fandom.com/es/wiki/Ara%C3%B1a_Saltarina')
hombreDeNieveGigante = URIRef('https://onepunchman.fandom.com/es/wiki/Hombre_de_Nieve_Gigante')
himawari = URIRef('https://onepunchman.fandom.com/es/wiki/Himawari')
hotDog= URIRef('https://onepunchman.fandom.com/es/wiki/Hot-Dog')
gigakigan = URIRef('https://onepunchman.fandom.com/es/wiki/Gigakigan')
delorean = URIRef('https://onepunchman.fandom.com/es/wiki/Delorean')
fantasmaDeTresOjos = URIRef('https://onepunchman.fandom.com/es/wiki/Fantasma_de_los_Tres_Ojos?action=edit&redlink=1')
scaledon = URIRef('https://onepunchman.fandom.com/es/wiki/Scaledon?action=edit&redlink=1')
esmalte = URIRef('https://onepunchman.fandom.com/es/wiki/Esmalte')
tostadoNegro = URIRef('https://onepunchman.fandom.com/es/wiki/Tostado_Negro?action=edit&redlink=1')
machoDaikon = URIRef('https://onepunchman.fandom.com/es/wiki/Macho_Daikon')
broteMarchito = URIRef('https://onepunchman.fandom.com/es/wiki/Brote_Marchito')
ranaToroPeleadora = URIRef('https://onepunchman.fandom.com/es/wiki/Rana-Toro_Peleadora?action=edit&redlink=1')

# %%
####Otros
##Artemarcialistas
bazuzu = URIRef('https://onepunchman.fandom.com/es/wiki/Bazuzu')
bomb = URIRef('https://onepunchman.fandom.com/es/wiki/Bomb')
charanko = URIRef('https://onepunchman.fandom.com/es/wiki/Charanko')
dave = URIRef('https://onepunchman.fandom.com/es/wiki/Dave')
gatlin = URIRef('https://onepunchman.fandom.com/es/wiki/Gatlin')
jakumen = URIRef('https://onepunchman.fandom.com/es/wiki/Jakumen')
linlin = URIRef('https://onepunchman.fandom.com/es/wiki/Lin_Lin')
mentai = URIRef('https://onepunchman.fandom.com/es/wiki/Mentai')
sourface = URIRef('https://onepunchman.fandom.com/es/wiki/Sour_Face')
suiryu = URIRef('https://onepunchman.fandom.com/es/wiki/Suiryu')
zakos = URIRef('https://onepunchman.fandom.com/es/wiki/Zakos')

##Espadachines
amahare = URIRef('https://onepunchman.fandom.com/es/wiki/Amahare')
nichirin = URIRef('https://onepunchman.fandom.com/es/wiki/Nichirin')
zanbai = URIRef('https://onepunchman.fandom.com/es/wiki/Zanbai')

##Escuadrón privado de Nainki
tongara = URIRef('https://onepunchman.fandom.com/es/wiki/Tongara')
noria = URIRef('https://onepunchman.fandom.com/es/wiki/Noria')
asami = URIRef('https://onepunchman.fandom.com/es/wiki/Asami')
chinpi = URIRef('https://onepunchman.fandom.com/es/wiki/Chinpi')

##Otros
drKuseno = URIRef('https://onepunchman.fandom.com/es/wiki/Dr._Kuseno')
shibawa = URIRef('https://onepunchman.fandom.com/es/wiki/Shibabawa')
niñoBarbilla = URIRef('https://onepunchman.fandom.com/es/wiki/Ni%C3%B1o_de_la_barbilla_partida')
anunciador = URIRef('https://onepunchman.fandom.com/es/wiki/Anunciador_de_S%C3%BAper_Lucha')
tacchan = URIRef('https://onepunchman.fandom.com/es/wiki/Tacchan')
tareo = URIRef('https://onepunchman.fandom.com/es/wiki/Tareo')
waganma = URIRef('https://onepunchman.fandom.com/es/wiki/Waganma')
zeniru = URIRef('https://onepunchman.fandom.com/es/wiki/Zeniru')
zenko = URIRef('https://onepunchman.fandom.com/es/wiki/Zenko')

# %%
## Técnicas

#Cuerpo a Cuerpo
ArteAsesinoDelInfiernoOscuro = URIRef('https://onepunchman.fandom.com/es/wiki/Arte_Asesino_del_Infierno_Oscuro')
GolpeMortal = URIRef('https://onepunchman.fandom.com/es/wiki/Golpe_Mortal')
EstiloDelCaminoAspero = URIRef('https://onepunchman.fandom.com/es/wiki/Estilo_del_Camino_%C3%81spero')
GolpeDeCabezaGrave = URIRef('https://onepunchman.fandom.com/es/wiki/Golpe_de_Cabeza_Grave')
GolpeGrave = URIRef('https://onepunchman.fandom.com/es/wiki/Golpe_Grave')
Ninjutsu = URIRef('https://onepunchman.fandom.com/es/wiki/Ninjutsu')
PuñoAsesinoDelMonstruoDiosDeLaCalamidad = URIRef('https://onepunchman.fandom.com/es/wiki/Pu%C3%B1o_Asesino_del_Monstruo_Dios_de_la_Calamidad')
PuñoDeAguaQueFluyeRocaAplastante = URIRef('https://onepunchman.fandom.com/es/wiki/Pu%C3%B1o_de_Agua_que_fluye_Roca_Aplastante')
PuñoDeCorteDeHierroTorbellino = URIRef('https://onepunchman.fandom.com/es/wiki/Pu%C3%B1o_de_Corte_de_Hierro_Torbellino')
PuñoVacio = URIRef('https://onepunchman.fandom.com/es/wiki/Pu%C3%B1o_Vac%C3%ADo')
SuperalloyBazooka = URIRef('https://onepunchman.fandom.com/es/wiki/Superalloy_Bazooka')

#ProyeccionDeEnergia
CañónDeEstrellaQueColapsa = URIRef('https://onepunchman.fandom.com/es/wiki/Ca%C3%B1%C3%B3n_de_Estrella_que_Colapsa')

#Tecnica Ofensiva
CorteAtomico = URIRef('https://onepunchman.fandom.com/es/wiki/Corte_At%C3%B3mico')
DestelloRayo = URIRef('https://onepunchman.fandom.com/es/wiki/Destello_Rayo')
GolpeAmetralladora = URIRef('https://onepunchman.fandom.com/es/wiki/Golpe_Ametralladora')
GolpeLeon = URIRef('https://onepunchman.fandom.com/es/wiki/Golpe_Le%C3%B3n')
GolpesNormalesConsecutivos = URIRef('https://onepunchman.fandom.com/es/wiki/Golpes_Normales_Consecutivos')
Incinerar = URIRef('https://onepunchman.fandom.com/es/wiki/Incinerar')

#Combate a Distancia
SaltosLateralesGraves = URIRef('https://onepunchman.fandom.com/es/wiki/Saltos_Laterales_Graves')
VolteoDeTablaGrave = URIRef('https://onepunchman.fandom.com/es/wiki/Volteo_de_Tabla_Grave')

# %%
g= Graph()

# %% [markdown]
# ### Agregando los tipos de ocupación de los personajes

# %%
heroes = URIRef('https://onepunchman.fandom.com/es/wiki/Personajes#H.C3.A9roes')
villanos = URIRef('https://onepunchman.fandom.com/es/wiki/Personajes#Villanos')
otros = URIRef('https://onepunchman.fandom.com/es/wiki/Personajes#Otros')

g.add((heroes, RDFS.subClassOf, n.char_class))
g.add((villanos, RDFS.subClassOf, n.char_class))
g.add((otros, RDFS.subClassOf, n.char_class))

g.add((heroes, name, Literal('Heroes')))
g.add((villanos, name, Literal('Villanos')))
g.add((otros, name, Literal('Otros')))

g.add((name, RDFS.subPropertyOf, RDFS.label))

# %% [markdown]
# ### Agregando las subclases de Heroes, Villanos y Otros

# %%
#Héroes
g.add((n.hero_association, RDFS.subClassOf, heroes))
g.add((n.unknown_class, RDFS.subClassOf, heroes))
g.add((n.ex_heros, RDFS.subClassOf, heroes))
g.add((n.personal, RDFS.subClassOf, heroes))

#Villanos
g.add((n.house_of_evolution, RDFS.subClassOf, villanos))
g.add((n.criminal, RDFS.subClassOf, villanos))
g.add((n.anti_heros, RDFS.subClassOf, villanos))
g.add((n.anti_villans, RDFS.subClassOf, villanos))
g.add((n.ex_villans, RDFS.subClassOf, villanos))

#Otros
g.add((n.martial_art, RDFS.subClassOf, otros))
g.add((n.swordsman, RDFS.subClassOf, otros))
g.add((n.private_squadron_of_nainki, RDFS.subClassOf, otros))
g.add((n.others, RDFS.subClassOf, otros))

#print(g.serialize(format = 'xml').decode('utf8'))

# %%
g.add((n.hero_association, name, Literal('Asociación de Héroes')))
g.add((n.unknown_class, name, Literal('Clases desconocidas')))
g.add((n.ex_heros, name, Literal('Ex Héroes')))
g.add((n.personal, name, Literal('Personal de la Asociación')))

g.add((n.house_of_evolution, name, Literal('Casa de la Evolución')))
g.add((n.criminal, name, Literal('Criminales')))
g.add((n.anti_heros, name, Literal('Anti Héroes')))
g.add((n.anti_villans, name, Literal('Anti Villanos')))
g.add((n.ex_villans, name, Literal('Ex Villanos')))

g.add((n.martial_art, name, Literal('Marcialistas')))
g.add((n.swordsman, name, Literal('Espadachines')))
g.add((n.private_squadron_of_nainki, name, Literal('Escuadrón privado de Nainki')))
g.add((n.others, name, Literal('Otros personajes')))

g.add((name, RDFS.subPropertyOf, RDFS.label))

# %% [markdown]
# ### Agregando clases en Asociación de Héroes

# %%
claseS = URIRef('https://onepunchman.fandom.com/es/wiki/Personajes#Clase-S')
claseA = URIRef('https://onepunchman.fandom.com/es/wiki/Personajes#Clase-A')
claseB = URIRef('https://onepunchman.fandom.com/es/wiki/Personajes#Clase-B')
claseC = URIRef('https://onepunchman.fandom.com/es/wiki/Personajes#Clase-C')

g.add((claseS, RDFS.subClassOf, n.hero_association))
g.add((claseA, RDFS.subClassOf, n.hero_association))
g.add((claseB, RDFS.subClassOf, n.hero_association))
g.add((claseC, RDFS.subClassOf, n.hero_association))

# %% [markdown]
# ### Agregando clases en Casa de la Evolución

# %%
ladrones = URIRef('https://onepunchman.fandom.com/es/wiki/Personajes#Ladrones_de_Materia_Oscura')
laOrganizacion = URIRef('https://onepunchman.fandom.com/es/wiki/Personajes#La_Organizaci.C3.B3n')
habiDeLasProfundidades = URIRef('https://onepunchman.fandom.com/es/wiki/Personajes#Habitantes_de_las_Profundidades')
seaFolk = URIRef('https://onepunchman.fandom.com/es/wiki/Personajes#Seafolk')
skyFolk = URIRef('https://onepunchman.fandom.com/es/wiki/Personajes#Skyfolk')
dinoFolk = URIRef('https://onepunchman.fandom.com/es/wiki/Personajes#Dinofolk')
sinAfiliacion = URIRef('https://onepunchman.fandom.com/es/wiki/Personajes#Sin_Afiliaci.C3.B3n')
asoDeMonstruos = URIRef('https://onepunchman.fandom.com/es/wiki/Personajes#Asociaci.C3.B3n_de_Monstruos')

g.add((ladrones, RDFS.subClassOf, n.house_of_evolution))
g.add((laOrganizacion, RDFS.subClassOf, n.house_of_evolution))
g.add((habiDeLasProfundidades, RDFS.subClassOf, n.house_of_evolution))
g.add((seaFolk, RDFS.subClassOf, n.house_of_evolution))
g.add((skyFolk, RDFS.subClassOf, n.house_of_evolution))
g.add((dinoFolk, RDFS.subClassOf, n.house_of_evolution))
g.add((sinAfiliacion, RDFS.subClassOf, n.house_of_evolution))
g.add((asoDeMonstruos, RDFS.subClassOf, n.house_of_evolution))


#print(g.serialize(format = 'xml').decode('utf8'))

# %% [markdown]
# ### Agregando clase Técnicas

# %%
tecnicas = URIRef('https://onepunchman.fandom.com/es/wiki/Categoría:Técnicas')

g.add((n.melee, RDFS.subClassOf, tecnicas))
g.add((n.nrg_proyection, RDFS.subClassOf, tecnicas))
g.add((n.offensive_tecnique, RDFS.subClassOf, tecnicas))
g.add((n.range_combat, RDFS.subClassOf, tecnicas))

#print(g.serialize(format = 'xml').decode('utf8'))

# %% [markdown]
# ### Agregando los nombres literales a las técnicas

# %%
g.add((n.melee, name, Literal('Cuerpo a Cuerpo')))
g.add((n.nrg_proyection, name, Literal('Proyeccion de Energia')))
g.add((n.offensive_technique, name, Literal('Tecnica ofensiva')))
g.add((n.range_combat, name, Literal('Combate a distancia')))

g.add((name, RDFS.subPropertyOf, RDFS.label))

#print(g.serialize(format='xml').decode('utf8'))

# %% [markdown]
# ### Agreando los personajes de la Asociación de Héroes

# %%
####Heroes
###Asociacion de Heroes
##Clase S

g.add((blast, name, Literal('Blast')))
g.add((blast, RDF.type, claseS))
g.add((blast, rank, Literal(1)))
g.add((blast, alias, Literal('Blast')))

g.add((tatsumaki , name, Literal('Tatsumaki')))
g.add((tatsumaki , RDF.type, claseS))
g.add((tatsumaki , rank, Literal(2)))
g.add((tatsumaki, edad, Literal(28)))
g.add((tatsumaki , alias, Literal('Tornado del Terror')))

g.add((bang, name, Literal('Bang')))
g.add((bang, RDF.type, claseS))
g.add((bang, rank, Literal(3)))
g.add((bang, edad, Literal(81)))
g.add((bang, alias, Literal('Silver Fang')))

g.add((kamikaze, name, Literal('Kamikaze')))
g.add((kamikaze, RDF.type, claseS))
g.add((kamikaze, rank, Literal(4)))
g.add((kamikaze, edad, Literal(37)))
g.add((kamikaze, alias, Literal('Atomic Samurai')))

g.add((kidEmperor, name, Literal('Kid Emperor')))
g.add((kidEmperor, RDF.type, claseS))
g.add((kidEmperor, rank, Literal(5)))
g.add((kidEmperor, edad, Literal(10)))
g.add((kidEmperor, alias, Literal('Kid Emperor')))

g.add((metalKnight , name, Literal('Dr. Bofoi')))
g.add((metalKnight , RDF.type, claseS))
g.add((metalKnight , rank, Literal(6)))
g.add((metalKnight , alias, Literal('Metal Knight')))

g.add((king, name, Literal('King')))
g.add((king, RDF.type, claseS))
g.add((king, rank, Literal(7)))
g.add((king, edad, Literal(29)))
g.add((king, alias, Literal('El hombre más fuerte de la tierra')))

g.add((zombieman , name, Literal('Zombieman')))
g.add((zombieman , RDF.type, claseS))
g.add((zombieman , rank, Literal(8)))
g.add((zombieman , alias, Literal('N.66')))

g.add((driveKnight , name, Literal('Drive Knight')))
g.add((driveKnight , RDF.type, claseS))
g.add((driveKnight , rank, Literal(9)))
g.add((driveKnight , alias, Literal('Drive Knight')))

g.add((pigGod , name, Literal('Pig God')))
g.add((pigGod , RDF.type, claseS))
g.add((pigGod , rank, Literal(10)))
g.add((pigGod , alias, Literal('Pig God')))

g.add((darkshine , name, Literal('Superalloy Darkshine')))
g.add((darkshine , RDF.type, claseS))
g.add((darkshine , rank, Literal(11)))
g.add((darkshine , edad, Literal(27)))
g.add((darkshine , alias, Literal('Superalloy Darkshine')))

g.add((watchdog  , name, Literal('Watchdog Man')))
g.add((watchdog  , RDF.type, claseS))
g.add((watchdog  , rank, Literal(12)))
g.add((watchdog  , alias, Literal('Guardián de Ciudad-Q ')))

g.add((flashy, name, Literal('Flashy Flash')))
g.add((flashy, RDF.type, claseS))
g.add((flashy, rank, Literal(13)))
g.add((flashy, edad, Literal(25)))
g.add((flashy, alias, Literal('Flashy Flash')))

g.add((genos , name, Literal('Genos')))
g.add((genos , RDF.type, claseS))
g.add((genos , rank, Literal(14)))
g.add((genos , edad, Literal(19)))
g.add((genos , alias, Literal('Cíborg Demoníaco')))

g.add((bad , name, Literal('Baddo')))
g.add((bad , RDF.type, claseS))
g.add((bad , rank, Literal(15)))
g.add((bad , edad, Literal(17)))
g.add((bad , alias, Literal('Metal Bat')))

g.add((tanktop , name, Literal('Tanktop Master')))
g.add((tanktop , RDF.type, claseS))
g.add((tanktop , rank, Literal(16)))
g.add((tanktop , alias, Literal('Tanktop Master')))

g.add((lindolindo , name, Literal('Prisionero Lindo-Lindo')))
g.add((lindolindo , RDF.type, claseS))
g.add((lindolindo , rank, Literal(17)))
g.add((lindolindo , edad, Literal(33)))
g.add((lindolindo , alias, Literal('Prisionero Lindo-Lindo')))

##Clase A
g.add((amai, name, Literal('Handsome Kamen Amai Mask')))
g.add((amai, RDF.type, claseA))
g.add((amai, rank, Literal(1)))
g.add((amai, edad, Literal(24)))
g.add((amai, alias, Literal('Handsome Kamen Amai Mask')))

g.add((iaian , name, Literal('Iaian')))
g.add((iaian , RDF.type, claseA))
g.add((iaian , rank, Literal(2)))
g.add((iaian , edad, Literal(23)))
g.add((iaian , alias, Literal('Iaian')))

g.add((okamaitachi, name, Literal('Okamaitachi ')))
g.add((okamaitachi, RDF.type, claseA))
g.add((okamaitachi, rank, Literal(3)))
g.add((okamaitachi, edad, Literal(26)))
g.add((okamaitachi, alias, Literal('Okamaitachi ')))

g.add((bushidrill , name, Literal('Bushidrill')))
g.add((bushidrill , RDF.type, claseA))
g.add((bushidrill , rank, Literal(4)))
g.add((bushidrill , edad, Literal(37)))
g.add((bushidrill , alias, Literal('Bushidrill')))

g.add((fundoshi , name, Literal('Heavy Tank Fundoshi')))
g.add((fundoshi , RDF.type, claseA))
g.add((fundoshi , rank, Literal(5)))
g.add((fundoshi , edad, Literal(35)))
g.add((fundoshi , alias, Literal('Heavy Tank Fundoshi')))

g.add((blueFire, name, Literal('Blue Fire')))
g.add((blueFire, RDF.type, claseA))
g.add((blueFire, rank, Literal(6)))
g.add((blueFire, edad, Literal(19)))
g.add((blueFire, alias, Literal('Blue Fire')))

g.add((gatling , name, Literal('Death Gatling')))
g.add((gatling , RDF.type, claseA))
g.add((gatling , rank, Literal(8)))
g.add((gatling , alias, Literal('Death Gatling')))

g.add((stinger, name, Literal('Stinger')))
g.add((stinger, RDF.type, claseA))
g.add((stinger, rank, Literal(10)))
g.add((stinger, edad, Literal(24)))
g.add((stinger, alias, Literal('Stinger')))

g.add((twinTail , name, Literal('Twin Tail')))
g.add((twinTail , RDF.type, claseA))
g.add((twinTail , rank, Literal(11)))
g.add((twinTail , alias, Literal('Twin Tail')))

g.add((filosofo , name, Literal('Gran Filósofo')))
g.add((filosofo , RDF.type, claseA))
g.add((filosofo , rank, Literal(13)))
g.add((filosofo , alias, Literal('Gran Hombre de Hierro')))

g.add((butterfly , name, Literal('Butterfly DX')))
g.add((butterfly , RDF.type, claseA))
g.add((butterfly , rank, Literal(16)))
g.add((butterfly , alias, Literal('Butterfly DX')))

g.add((genji, name, Literal('Genji ')))
g.add((genji, RDF.type, claseA))
g.add((genji, rank, Literal(17)))
g.add((genji, edad, Literal(24)))
g.add((genji, alias, Literal('Lightning Genji')))

g.add((maxx , name, Literal('Max ')))
g.add((maxx , RDF.type, claseA))
g.add((maxx , rank, Literal(19)))
g.add((maxx , edad, Literal(21)))
g.add((maxx , alias, Literal('Lightning Max')))

g.add((oneShooter , name, Literal('One Shooter')))
g.add((oneShooter , RDF.type, claseA))
g.add((oneShooter , rank, Literal(22)))
g.add((oneShooter , alias, Literal('One Shooter')))

g.add((green , name, Literal('Green ')))
g.add((green , RDF.type, claseA))
g.add((green , rank, Literal(24)))
g.add((green , alias, Literal('Green ')))

g.add((eyebroll , name, Literal('Crescent Eyebroll')))
g.add((eyebroll , RDF.type, claseA))
g.add((eyebroll , rank, Literal(25)))
g.add((eyebroll , alias, Literal('Crescent Eyebroll')))

##Clase B

g.add((fubuki, name, Literal('Fubuki ')))
g.add((fubuki, RDF.type, claseB))
g.add((fubuki, rank, Literal(1)))
g.add((fubuki, edad, Literal(23)))
g.add((fubuki, alias, Literal('Ventisca del Infierno')))

g.add((pestañas, name, Literal('Pestañas ')))
g.add((pestañas, RDF.type, claseB))
g.add((pestañas, rank, Literal(1)))
g.add((pestañas, edad, Literal(23)))
g.add((pestañas, alias, Literal('Pestañas')))

g.add((mono , name, Literal('Mono de Montaña ')))
g.add((mono , RDF.type, claseB))
g.add((mono , rank, Literal(3)))
g.add((mono , alias, Literal('Mono de Montaña')))

g.add((saitama , name, Literal('Saitama ')))
g.add((saitama , RDF.type, claseB))
g.add((saitama , rank, Literal(7)))
g.add((saitama , edad, Literal(25)))
g.add((saitama , alias, Literal('Calvo con Capa')))
g.add((saitama , alias, Literal('Maestro ')))
g.add((saitama , alias, Literal('Charanko')))

g.add((wildHorn , name, Literal('Wild Horn')))
g.add((wildHorn , RDF.type, claseB))
g.add((wildHorn , rank, Literal(8)))
g.add((wildHorn , alias, Literal('Wild Horn')))

g.add((gafas , name, Literal('Gafas ')))
g.add((gafas , RDF.type, claseB))
g.add((gafas , rank, Literal(20)))
g.add((gafas , alias, Literal('Gafas')))

g.add((avispon , name, Literal('Avispón Rosa')))
g.add((avispon , RDF.type, claseB))
g.add((avispon , rank, Literal(25)))
g.add((avispon , alias, Literal('Técnica Comercial Callejera')))

g.add((smellMaster , name, Literal('Smell Master')))
g.add((smellMaster , RDF.type, claseB))
g.add((smellMaster , rank, Literal(38)))
g.add((smellMaster , alias, Literal('Smell Master')))

g.add((reclusamurai , name, Literal('Reclusamurai ')))
g.add((reclusamurai , RDF.type, claseB))
g.add((reclusamurai , rank, Literal(39)))
g.add((reclusamurai , alias, Literal('Reclusamurai')))

g.add((gungun , name, Literal('Gun Gun')))
g.add((gungun , RDF.type, claseB))
g.add((gungun , rank, Literal(43)))
g.add((gungun , alias, Literal('Gun Gun')))

g.add((carnicero, name, Literal('Carnicero')))
g.add((carnicero, RDF.type, claseB))
g.add((carnicero, rank, Literal(49)))
g.add((carnicero, alias, Literal('Carnicero')))

g.add((niceGuy, name, Literal('Jet Nice Guy')))
g.add((niceGuy, RDF.type, claseB))
g.add((niceGuy, rank, Literal(50)))
g.add((niceGuy, edad, Literal(26)))
g.add((niceGuy, alias, Literal('Jet Nice Guy')))

g.add((cuchillaOscura, name, Literal('Cuchilla Oscura')))
g.add((cuchillaOscura, RDF.type, claseB))
g.add((cuchillaOscura, rank, Literal(53)))
g.add((cuchillaOscura, edad, Literal(20)))
g.add((cuchillaOscura, alias, Literal('Cuchilla Oscura')))

g.add((needleStar , name, Literal('Needle Star')))
g.add((needleStar , RDF.type, claseB))
g.add((needleStar , rank, Literal(60)))
g.add((needleStar , alias, Literal('Needle Star')))

g.add((piko  , name, Literal('Piko')))
g.add((piko  , RDF.type, claseB))
g.add((piko  , rank, Literal(65)))
g.add((piko  , alias, Literal('Piko')))

##Clase C

g.add((satoru, name, Literal('Satoru ')))
g.add((satoru, RDF.type, claseC))
g.add((satoru, rank, Literal(1)))
g.add((satoru, edad, Literal(25)))
g.add((satoru, alias, Literal('Ciclista sin Licencia')))

g.add((biningShell , name, Literal('Strange Binding Shell')))
g.add((biningShell , RDF.type, claseC))
g.add((biningShell , rank, Literal(3)))
g.add((biningShell , alias, Literal('Strange Binding Shell')))

g.add((tiger, name, Literal('Tanktop Tiger')))
g.add((tiger, RDF.type, claseC))
g.add((tiger, rank, Literal(13)))
g.add((tiger, edad, Literal(25)))
g.add((tiger, alias, Literal('Tanktop Tiger')))

g.add((dPad, name, Literal('D-Pad')))
g.add((dPad, RDF.type, claseC))
g.add((dPad, rank, Literal(22)))
g.add((dPad, alias, Literal('D-Pad')))

g.add((tirantes, name, Literal('Tirantes Fúnebres')))
g.add((tirantes, RDF.type, claseC))
g.add((tirantes, rank, Literal(13)))
g.add((tirantes, edad, Literal(40)))
g.add((tirantes, alias, Literal('Tirantes Fúnebres')))

g.add((luchadorComida , name, Literal('Luchador de Comida Futoshi')))
g.add((luchadorComida , RDF.type, claseC))
g.add((luchadorComida , rank, Literal(66)))
g.add((luchadorComida , alias, Literal('Luchador de Comida Futoshi')))

g.add((hombreBateria, name, Literal('Hombre Batería')))
g.add((hombreBateria, RDF.type, claseC))
g.add((hombreBateria, rank, Literal(85)))
g.add((hombreBateria, alias, Literal('Hombre Batería')))

g.add((redMuffler , name, Literal('Red Muffler')))
g.add((redMuffler , RDF.type, claseC))
g.add((redMuffler , rank, Literal(20)))
g.add((redMuffler , edad, Literal(89)))
g.add((redMuffler , alias, Literal('Red Muffler')))

g.add((recepcionista, name, Literal('Recepcionista Blindado')))
g.add((recepcionista, RDF.type, claseC))
g.add((recepcionista, rank, Literal(111)))
g.add((recepcionista, alias, Literal('Recepcionista Blindado')))

g.add((gearsper , name, Literal('Gearsper')))
g.add((gearsper , RDF.type, claseC))
g.add((gearsper , rank, Literal(133)))
g.add((gearsper , alias, Literal('Gearsper')))

g.add((vaquero , name, Literal('Vaquero con Máscara de Gas')))
g.add((vaquero , RDF.type, claseC))
g.add((vaquero , rank, Literal(141)))
g.add((vaquero , alias, Literal('Vaquero con Máscara de Gas')))

g.add((octavaTumba, name, Literal('Octava Tumba')))
g.add((octavaTumba, RDF.type, claseC))
g.add((octavaTumba, rank, Literal(174)))
g.add((octavaTumba, alias, Literal('Octava Tumba')))

g.add((ecoloG , name, Literal('Ecolo G')))
g.add((ecoloG , RDF.type, claseC))
g.add((ecoloG , rank, Literal(179)))
g.add((ecoloG , alias, Literal('Ecolo G')))

g.add((monocross , name, Literal('Monocross')))
g.add((monocross , RDF.type, claseC))
g.add((monocross , rank, Literal(203)))
g.add((monocross , alias, Literal('Monocross')))

g.add((hombreDinamita , name, Literal('Hombre Dinamita')))
g.add((hombreDinamita , RDF.type, claseC))
g.add((hombreDinamita , rank, Literal(221)))
g.add((hombreDinamita , alias, Literal('Hombre Dinamita')))

#print(g.serialize(format='xml').decode('utf8'))

# %% [markdown]
# ### Agregando personajes de Clase Desconocida

# %%
###Clase Desconocida

g.add((tanktopRockabilly, name, Literal('Tanktop Rockabilly')))
g.add((tanktopRockabilly, RDF.type, n.unknown_class))
g.add((tanktopRockabilly, alias, Literal('Tanktop Rockabilly')))

g.add((tanktopGirl , name, Literal('Tanktop Girl')))
g.add((tanktopGirl , RDF.type, n.unknown_class))
g.add((tanktopGirl , alias, Literal('Tanktop Girl')))

g.add((tanktopRacer , name, Literal('Tanktop Racer')))
g.add((tanktopRacer , RDF.type, n.unknown_class))
g.add((tanktopRacer , alias, Literal('Tanktop Racer')))

g.add((tanktopHatter , name, Literal('Tanktop Hatter')))
g.add((tanktopHatter , RDF.type, n.unknown_class))
g.add((tanktopHatter , alias, Literal('Tanktop Hatter')))

g.add((tanktopJungle, name, Literal('Tanktop Jungle')))
g.add((tanktopJungle, RDF.type, n.unknown_class))
g.add((tanktopJungle, alias, Literal('Tanktop Jungle')))

g.add((tanktopSwimmer , name, Literal('Tanktop Swimmer')))
g.add((tanktopSwimmer , RDF.type, n.unknown_class))
g.add((tanktopSwimmer , alias, Literal('Tanktop Swimmer')))

g.add((tanktopMask , name, Literal('Tanktop Mask')))
g.add((tanktopMask , RDF.type, n.unknown_class))
g.add((tanktopMask , alias, Literal('Tanktop Mask')))

g.add((pandaman , name, Literal('Pandaman')))
g.add((pandaman , RDF.type, n.unknown_class))
g.add((pandaman , alias, Literal('Pandaman')))

#print(g.serialize(format='xml').decode('utf8'))

# %% [markdown]
# ### Agregando clase Ex-Héroes

# %%
### Ex-Heroes

g.add((allBackMan  , name, Literal('All Back-Man')))
g.add((allBackMan  , RDF.type, n.ex_heros))
g.add((allBackMan, edad, Literal(26)))
g.add((allBackMan  , alias, Literal('All Back-Man')))

g.add((serialBomber, name, Literal('Serial Bomber')))
g.add((serialBomber, RDF.type, n.ex_heros))
g.add((serialBomber, alias, Literal('Serial Bomber')))

g.add((graduadoDePostgrado , name, Literal('Graduado de Posgrado')))
g.add((graduadoDePostgrado , RDF.type, n.ex_heros))
g.add((graduadoDePostgrado , alias, Literal('Graduado de Posgrado')))

g.add((tanktopVegetarian   , name, Literal('Tanktop Vegetarian')))
g.add((tanktopVegetarian   , RDF.type, n.ex_heros))
g.add((tanktopVegetarian , edad, Literal(26)))
g.add((tanktopVegetarian   , alias, Literal('Tanktop Vegetarian')))

# %% [markdown]
# ### Agregando clase Personal de la Asociación de Héroes

# %%
### Personal de la Asociación de Héroes

g.add((agoni, name, Literal('Agoni')))
g.add((agoni, RDF.type, n.personal))
g.add((agoni, alias, Literal('Agoni')))

g.add((trabajadorBarbado, name, Literal('Trabajador Barbado')))
g.add((trabajadorBarbado, RDF.type, n.personal))
g.add((trabajadorBarbado, alias, Literal('Trabajador Barbado')))

g.add((trabajadorConGafas , name, Literal('Trabajador con Gafas')))
g.add((trabajadorConGafas , RDF.type, n.personal))
g.add((trabajadorConGafas , alias, Literal('Trabajador con Gafas')))

g.add((operadoraRamaC , name, Literal('Operador de la Rama C')))
g.add((operadoraRamaC , RDF.type, n.personal))
g.add((operadoraRamaC , alias, Literal('Operador de la Rama C')))

g.add((trabajadorRamaC , name, Literal('Trabajador de la Rama C')))
g.add((trabajadorRamaC , RDF.type, n.personal))
g.add((trabajadorRamaC , alias, Literal('Trabajador de la Rama C')))

g.add((operadoraDeConsola , name, Literal('Operadora de Consola')))
g.add((operadoraDeConsola , RDF.type, n.personal))
g.add((operadoraDeConsola , alias, Literal('Operadora de Consola')))

g.add((guiches , name, Literal('Guiches')))
g.add((guiches , RDF.type, n.personal))
g.add((guiches , alias, Literal('Guiches')))

g.add((operadoraRamaPrincipal , name, Literal('Operadora de la Rama Principal')))
g.add((operadoraRamaPrincipal , RDF.type, n.personal))
g.add((operadoraRamaPrincipal , alias, Literal('Operadora de la Rama Principal')))

g.add((mcCoy , name, Literal('McCoy')))
g.add((mcCoy , RDF.type, n.personal))
g.add((mcCoy , alias, Literal('McCoy')))

g.add((narinko , name, Literal('Narinki')))
g.add((narinko , RDF.type, n.personal))
g.add((narinko , alias, Literal('Narinki')))

g.add((sekingar , name, Literal('Sekingar')))
g.add((sekingar , RDF.type, n.personal))
g.add((sekingar , alias, Literal('Sekingar')))

g.add((chicaRefugioSiete , name, Literal('Chica del Refugio N.7')))
g.add((chicaRefugioSiete , RDF.type, n.personal))
g.add((chicaRefugioSiete , alias, Literal('Chica del Refugio N.7')))

g.add((sitch , name, Literal('Sitch')))
g.add((sitch , RDF.type, n.personal))
g.add((sitch , alias, Literal('Sitch')))

g.add((zeimeet , name, Literal('Zeimeet')))
g.add((zeimeet , RDF.type, n.personal))
g.add((zeimeet , alias, Literal('Zeimeet')))

g.add((operadoraRamaZ , name, Literal('Operadora de la Rama Z')))
g.add((operadoraRamaZ , RDF.type, n.personal))
g.add((operadoraRamaZ , alias, Literal('Operadora de la Rama Z')))

g.add((chicaComiteRamaZ , name, Literal('Chica del comité de la Rama Z')))
g.add((chicaComiteRamaZ , RDF.type, n.personal))
g.add((chicaComiteRamaZ , alias, Literal('Chica del comité de la Rama Z')))

g.add((chicaComiteEspecial , name, Literal('Chica del comité especial')))
g.add((chicaComiteEspecial , RDF.type, n.personal))
g.add((chicaComiteEspecial , alias, Literal('Chica del comité especial')))

#print(g.serialize(format='xml').decode('utf8'))

# %% [markdown]
# ### Agregando clases de La casa de la Evolucion

# %%
### Casa de la Evolución

g.add((asuraKabuto, name, Literal('Asura Kabuto')))
g.add((asuraKabuto, RDF.type, n.house_of_evolution))
g.add((asuraKabuto, rank, Literal('Dragon')))
g.add((asuraKabuto, alias, Literal('El 1° de la Casa de la Evolución')))

g.add((beastKing , name, Literal('Beast King')))
g.add((beastKing , RDF.type, n.house_of_evolution))
g.add((beastKing , rank, Literal('Ogro')))
g.add((beastKing  , alias, Literal('Beast King')))

g.add((gorilaBlindado, name, Literal('Gorila Blindado')))
g.add((gorilaBlindado, RDF.type, n.house_of_evolution))
g.add((gorilaBlindado, rank, Literal('Ogro')))
g.add((gorilaBlindado, alias, Literal('Gorila Blindado')))

g.add((chicaMosquito, name, Literal('Chica Mosquito')))
g.add((chicaMosquito, RDF.type, n.house_of_evolution))
g.add((chicaMosquito, rank, Literal('Ogro')))
g.add((chicaMosquito, alias, Literal('Chica Mosquito')))

g.add((mantis , name, Literal('Mantis')))
g.add((mantis , RDF.type, n.house_of_evolution))
g.add((mantis , rank, Literal('Tigre')))
g.add((mantis , alias, Literal('Mantis')))

g.add((groundDragon , name, Literal('Ground Dragon')))
g.add((groundDragon , RDF.type, n.house_of_evolution))
g.add((groundDragon , rank, Literal('Tigre')))
g.add((groundDragon , alias, Literal('Ground Dragon')))

g.add((slugerous , name, Literal('Slugerous')))
g.add((slugerous , RDF.type, n.house_of_evolution))
g.add((slugerous , rank, Literal('Tigre')))
g.add((slugerous , alias, Literal('Slugerous')))

g.add((rana , name, Literal('Rana')))
g.add((rana , RDF.type, n.house_of_evolution))
g.add((rana , rank, Literal('Tigre')))
g.add((rana , alias, Literal('Rana')))

# %% [markdown]
# ### Agregando sub clase Ladrones de la Materia Oscura

# %%
### Ladrones de la Materia Oscura

g.add((boros , name, Literal('Boros ')))
g.add((boros , RDF.type, ladrones))
g.add((boros , rank, Literal('Dragon')))
g.add((boros , alias, Literal('Conquistador del Universo')))

g.add((geryuganshoop , name, Literal('Geryuganshoop')))
g.add((geryuganshoop , RDF.type, ladrones))
g.add((geryuganshoop , rank, Literal('Dragon')))
g.add((geryuganshoop , alias, Literal('Geryuganshoop')))

g.add((melzargard , name, Literal('Melzargard')))
g.add((melzargard , RDF.type, ladrones))
g.add((melzargard , rank, Literal('Dragon')))
g.add((melzargard , alias, Literal('Melzargard')))

g.add((groribas , name, Literal('Groribas')))
g.add((groribas , RDF.type, ladrones))
g.add((groribas , rank, Literal('Dragon')))
g.add((groribas , alias, Literal('Groribas')))

# %% [markdown]
# ### Agregando sub clase La Organización

# %%
### La Organización

g.add((G5, name, Literal('G5')))
g.add((G5, RDF.type, laOrganizacion))
g.add((G5, rank, Literal('Ogro')))
g.add((G5, alias, Literal('G5')))

g.add((G4, name, Literal('G4')))
g.add((G4, RDF.type, laOrganizacion))
g.add((G4, rank, Literal('Ogro')))
g.add((G4, alias, Literal('G4')))

# %% [markdown]
# ### Agregando sub clase Habitantes de las Profundidades

# %%
### Habitantes de las Profundidades

g.add((underlordDream, name, Literal('Underlord')))
g.add((underlordDream, RDF.type, habiDeLasProfundidades ))
g.add((underlordDream, rank, Literal('Ogro')))
g.add((underlordDream, alias, Literal('Underlord')))

g.add((habitantesDeLasProfundidades , name, Literal('Habitantes de las Profundidades')))
g.add((habitantesDeLasProfundidades , RDF.type, habiDeLasProfundidades ))
g.add((habitantesDeLasProfundidades, rank, Literal('Ogro')))
g.add((habitantesDeLasProfundidades, alias, Literal('Habitantes de las Profundidades')))

# %% [markdown]
# ### Agregando sub clase Seafolk

# %%
### Seafolk

g.add((reyDelMarProfundo, name, Literal('Rey del Mar Profundo')))
g.add((reyDelMarProfundo, RDF.type, seaFolk ))
g.add((reyDelMarProfundo, rank, Literal('Ogro')))
g.add((reyDelMarProfundo, alias, Literal('Rey del Mar Profundo')))

g.add((mensajeroSeafolk , name, Literal('Mensajero de los Marinos')))
g.add((mensajeroSeafolk , RDF.type, seaFolk ))
g.add((mensajeroSeafolk , rank, Literal('Lobo')))
g.add((mensajeroSeafolk , alias, Literal('Mensajero de los Marinos')))

g.add((lordGranBlanco , name, Literal('Lord Gran Blanco')))
g.add((lordGranBlanco , RDF.type, seaFolk ))
g.add((lordGranBlanco , rank, Literal('Unknown')))
g.add((lordGranBlanco , alias, Literal('Lord Gran Blanco')))

g.add((marinos , name, Literal('Marinos')))
g.add((marinos , RDF.type, seaFolk ))
g.add((marinos , alias, Literal('Marinos')))

g.add((anguilaDeUrna , name, Literal('Anguila de urna')))
g.add((anguilaDeUrna , RDF.type, seaFolk ))
g.add((anguilaDeUrna , rank, Literal('Tigre')))
g.add((anguilaDeUrna, alias, Literal('Anguila de urna')))

# %% [markdown]
# ### Agregando sub clase Skyfolk

# %%
### Skyfolk

g.add((skyKing , name, Literal('Sky King')))
g.add((skyKing , RDF.type, skyFolk  ))
g.add((skyKing , rank, Literal('Ogro')))
g.add((skyKing , alias, Literal('Sky King')))

g.add((aguila , name, Literal('Águila')))
g.add((aguila , RDF.type, skyFolk  ))
g.add((aguila , rank, Literal('Unknown')))
g.add((aguila , alias, Literal('Águila')))

g.add((halcon , name, Literal('Halcón')))
g.add((halcon , RDF.type, skyFolk  ))
g.add((halcon , rank, Literal('Unknown')))
g.add((halcon , alias, Literal('Halcón')))

g.add((gavilan , name, Literal('Gavilán')))
g.add((gavilan , RDF.type, skyFolk  ))
g.add((gavilan , rank, Literal('Unknown')))
g.add((gavilan , alias, Literal('Gavilán')))

g.add((cometa , name, Literal('Cometa')))
g.add((cometa , RDF.type, skyFolk  ))
g.add((cometa , rank, Literal('Unknown')))
g.add((cometa , alias, Literal('Cometa')))

# %% [markdown]
# ### Agregando sub clase Dinofolk

# %%
### Dinofolk

g.add((reyAntiguo , name, Literal('Rey Antiguo')))
g.add((reyAntiguo , RDF.type, dinoFolk  ))
g.add((reyAntiguo , rank, Literal('Unknown')))
g.add((reyAntiguo , alias, Literal('Rey Antiguo')))

# %% [markdown]
# ### Agregando sub clase Sin Afiliación

# %%
### Sin Afiliación

g.add((kanirante , name, Literal('Kanirante')))
g.add((kanirante , RDF.type, sinAfiliacion))
g.add((kanirante , rank, Literal('Tigre')))
g.add((kanirante , alias, Literal('Kanirante')))

g.add((marugori , name, Literal('Marugori')))
g.add((marugori , RDF.type, sinAfiliacion))
g.add((marugori , rank, Literal('Dragón')))
g.add((marugori , rank, Literal('Ogro')))
g.add((marugori , alias, Literal('Marugori')))

g.add((vaccineMan , name, Literal('Vaccine Man')))
g.add((vaccineMan , RDF.type, sinAfiliacion))
g.add((vaccineMan , rank, Literal('Dragón')))
g.add((vaccineMan , alias, Literal('Vaccine Man')))

g.add((bariCustom  , name, Literal('BariCustom YO649Z Mk. II')))
g.add((bariCustom  , RDF.type, sinAfiliacion))
g.add((bariCustom  , rank, Literal('Unknown')))
g.add((bariCustom  , alias, Literal('BariCustom YO649Z Mk. II')))

g.add((kombuInfinito, name, Literal('Kombu Infinito')))
g.add((kombuInfinito, RDF.type, sinAfiliacion))
g.add((kombuInfinito, rank, Literal('Ogro')))
g.add((kombuInfinito, alias, Literal('Kombu Infinito')))

g.add((gusanoDeTierra , name, Literal('Gusano de Tierra')))
g.add((gusanoDeTierra , RDF.type, sinAfiliacion))
g.add((gusanoDeTierra , rank, Literal('Unknown')))
g.add((gusanoDeTierra , alias, Literal('Gusano de Tierra')))

g.add((crazyBrownBear , name, Literal('Crazy Brown Bear')))
g.add((crazyBrownBear , RDF.type, sinAfiliacion))
g.add((crazyBrownBear , rank, Literal('Ogro')))
g.add((crazyBrownBear , alias, Literal('Crazy Brown Bear')))

g.add((lordOfMountains , name, Literal('Lord of Mountains')))
g.add((lordOfMountains , RDF.type, sinAfiliacion))
g.add((lordOfMountains , rank, Literal('Ogro')))
g.add((lordOfMountains , alias, Literal('Lord of Mountains')))

g.add((larvaMagiciada , name, Literal('Larva Magiciada de 170 000 Años')))
g.add((larvaMagiciada , RDF.type, sinAfiliacion))
g.add((larvaMagiciada , rank, Literal('Ogro')))
g.add((larvaMagiciada , alias, Literal('Larva Magiciada de 170 000 Años')))

g.add((cigarraAdulta , name, Literal('Cigarra Adulta de 170 000 Años')))
g.add((cigarraAdulta , RDF.type, sinAfiliacion))
g.add((cigarraAdulta , rank, Literal('Dragón')))
g.add((cigarraAdulta , alias, Literal('Cigarra Adulta de 170 000 Años')))

g.add((demonioVentilador , name, Literal('Demonio Ventilador')))
g.add((demonioVentilador , RDF.type, sinAfiliacion))
g.add((demonioVentilador , rank, Literal('Ogro')))
g.add((demonioVentilador , alias, Literal('Demonio Ventilador')))

g.add((piggyBacon , name, Literal('Piggy Bancon')))
g.add((piggyBacon , RDF.type, sinAfiliacion))
g.add((piggyBacon , rank, Literal('Lobo')))
g.add((piggyBacon , alias, Literal('Piggy Bancon')))

g.add((encarnacionDelCordonDelCableDeLuz, name, Literal('Encarnación del Cordón del cable de Luz')))
g.add((encarnacionDelCordonDelCableDeLuz, RDF.type, sinAfiliacion))
g.add((encarnacionDelCordonDelCableDeLuz, rank, Literal('Tigre')))
g.add((encarnacionDelCordonDelCableDeLuz, alias, Literal('Encarnación del Cordón del cable de Luz')))

g.add((surpriseAttackPlum , name, Literal('Surprise-Attack Plum')))
g.add((surpriseAttackPlum , RDF.type, sinAfiliacion))
g.add((surpriseAttackPlum , rank, Literal('Demonio')))
g.add((surpriseAttackPlum , alias, Literal('Surprise-Attack Plum')))

g.add((grizzlyNyah , name, Literal('Grizzly Nyah')))
g.add((grizzlyNyah , RDF.type, sinAfiliacion))
g.add((grizzlyNyah , rank, Literal('Demonio')))
g.add((grizzlyNyah , alias, Literal('Grizzly Nyah')))

g.add((gameBerus , name, Literal('Game-Berus')))
g.add((gameBerus , RDF.type, sinAfiliacion))
g.add((gameBerus , rank, Literal('Demonio')))
g.add((gameBerus , alias, Literal('Game-Berus')))

g.add((octopusClawMan , name, Literal('Octopus Claw Man')))
g.add((octopusClawMan , RDF.type, sinAfiliacion))
g.add((octopusClawMan , rank, Literal('Tigre')))
g.add((octopusClawMan , alias, Literal('Octopus Claw Man')))

g.add((suppon , name, Literal('Suppon')))
g.add((suppon , RDF.type, sinAfiliacion))
g.add((suppon , rank, Literal('Unknown')))
g.add((suppon , alias, Literal('Suppon')))

g.add((cuervoGigante , name, Literal('Cuervo Gigante')))
g.add((cuervoGigante , RDF.type, sinAfiliacion))
g.add((cuervoGigante , rank, Literal('Demonio')))
g.add((cuervoGigante , alias, Literal('Cuervo Gigante')))

g.add((tongueStretcher, name, Literal('Tongue Stretcher')))
g.add((tongueStretcher, RDF.type, sinAfiliacion))
g.add((tongueStretcher, rank, Literal('Lobo')))
g.add((tongueStretcher, alias, Literal('Tongue Stretcher')))

g.add((aranhaSaltarina , name, Literal('Araña Saltarina')))
g.add((aranhaSaltarina , RDF.type, sinAfiliacion))
g.add((aranhaSaltarina , rank, Literal('Demonio')))
g.add((aranhaSaltarina , alias, Literal('Araña Saltarina')))

g.add((hombreDeNieveGigante , name, Literal('Hombre de Nieve Gigante')))
g.add((hombreDeNieveGigante , RDF.type, sinAfiliacion))
g.add((hombreDeNieveGigante , rank, Literal('Demonio')))
g.add((hombreDeNieveGigante , alias, Literal('Hombre de Nieve Gigante')))

g.add((himawari, name, Literal('Himawari')))
g.add((himawari, RDF.type, sinAfiliacion))
g.add((himawari, rank, Literal('Tigre')))
g.add((himawari, alias, Literal('Himawari')))

g.add((hotDog, name, Literal('Hot-Dog')))
g.add((hotDog, RDF.type, sinAfiliacion))
g.add((hotDog, rank, Literal('Tigre')))
g.add((hotDog, alias, Literal('Hot-Dog')))

g.add((gigakigan , name, Literal('Gigakigan')))
g.add((gigakigan , RDF.type, sinAfiliacion))
g.add((gigakigan , rank, Literal('Unknown')))
g.add((gigakigan , alias, Literal('Gigakigan')))

g.add((delorean , name, Literal('Delorean')))
g.add((delorean , RDF.type, sinAfiliacion))
g.add((delorean , rank, Literal('Tigre')))
g.add((delorean , alias, Literal('Delorean')))

g.add((fantasmaDeTresOjos , name, Literal('Fantasma de los Tres Ojos')))
g.add((fantasmaDeTresOjos , RDF.type, sinAfiliacion))
g.add((fantasmaDeTresOjos , rank, Literal('Tigre')))
g.add((fantasmaDeTresOjos , alias, Literal('Fantasma de los Tres Ojos')))

g.add((scaledon , name, Literal('Scaledon')))
g.add((scaledon , RDF.type, sinAfiliacion))
g.add((scaledon , rank, Literal('Tigre')))
g.add((scaledon , rank, Literal('Demonio')))
g.add((scaledon , alias, Literal('Scaledon')))

g.add((esmalte , name, Literal('Esmalte')))
g.add((esmalte , RDF.type, sinAfiliacion))
g.add((esmalte , rank, Literal('Unknown')))
g.add((esmalte , alias, Literal('Esmalte')))

g.add((tostadoNegro , name, Literal('Tostado Negro')))
g.add((tostadoNegro , RDF.type, sinAfiliacion))
g.add((tostadoNegro , rank, Literal('Tigre')))
g.add((tostadoNegro , alias, Literal('Tostado Negro')))

g.add((machoDaikon , name, Literal('Macho Daikon')))
g.add((machoDaikon , RDF.type, sinAfiliacion))
g.add((machoDaikon , rank, Literal('Demonio')))
g.add((machoDaikon , alias, Literal('Macho Daikon')))

g.add((broteMarchito , name, Literal('Brote Marchito')))
g.add((broteMarchito , RDF.type, sinAfiliacion))
g.add((broteMarchito , rank, Literal('Tigre')))
g.add((broteMarchito , rank, Literal('Dragón')))
g.add((broteMarchito , alias, Literal('Brote Marchito')))

g.add((ranaToroPeleadora , name, Literal('Rana-Toro Peleadora')))
g.add((ranaToroPeleadora , RDF.type, sinAfiliacion))
g.add((ranaToroPeleadora , rank, Literal('Tigre')))
g.add((ranaToroPeleadora , alias, Literal('Rana-Toro Peleadora')))

# %% [markdown]
# ### Agregando clase Artemarcialistas

# %%
### Artemarcialistas

g.add((bazuzu , name, Literal('Bazuzu')))
g.add((bazuzu , RDF.type, n.martial_art))
g.add((bazuzu , alias, Literal('Bazuzu')))

g.add((bomb , name, Literal('Bomb')))
g.add((bomb , RDF.type, n.martial_art))
g.add((bomb , edad, Literal(82)))
g.add((bomb , alias, Literal('Bomb')))

g.add((charanko , name, Literal('Charanko')))
g.add((charanko , RDF.type, n.martial_art))
g.add((charanko , edad, Literal(18)))
g.add((charanko , alias, Literal('Charanko')))

g.add((dave , name, Literal('Dave')))
g.add((dave , RDF.type, n.martial_art))
g.add((dave , alias, Literal('Dave')))

g.add((gatlin , name, Literal('Gatlin')))
g.add((gatlin , RDF.type, n.martial_art))
g.add((gatlin , alias, Literal('Gatlin')))

g.add((jakumen , name, Literal('Jakumen')))
g.add((jakumen , RDF.type, n.martial_art))
g.add((jakumen , alias, Literal('Jakumen')))

g.add((linlin , name, Literal('Lin Lin')))
g.add((linlin , RDF.type, n.martial_art))
g.add((linlin , alias, Literal('Lin Lin')))

g.add((mentai , name, Literal('Mentai')))
g.add((mentai , RDF.type, n.martial_art))
g.add((mentai , alias, Literal('Mentai')))

g.add((sourface , name, Literal('Sour Face')))
g.add((sourface , RDF.type, n.martial_art))
g.add((sourface , edad, Literal(20)))
g.add((sourface , alias, Literal('Sour Face')))

g.add((suiryu , name, Literal('Suiryu')))
g.add((suiryu , RDF.type, n.martial_art))
g.add((suiryu , alias, Literal('Suiryu')))

g.add((zakos , name, Literal('Zakos')))
g.add((zakos , RDF.type, n.martial_art))
g.add((zakos , alias, Literal('Zakos')))

# %% [markdown]
# ### Agregando clase Espadachines

# %%
### Espadachines

g.add((amahare , name, Literal('Amahare')))
g.add((amahare , RDF.type, n.swordsman))
g.add((amahare , alias, Literal('Amahare')))

g.add((nichirin  , name, Literal('Nichirin')))
g.add((nichirin  , RDF.type, n.swordsman))
g.add((nichirin  , alias, Literal('Nichirin')))

g.add((zanbai  , name, Literal('Zanbai')))
g.add((zanbai  , RDF.type, n.swordsman))
g.add((zanbai  , alias, Literal('Zanbai')))

# %% [markdown]
# ### Agregando clase Escuadrón Privado de Nainki

# %%
### Escuadrón Privado de Nainki

g.add((tongara  , name, Literal('Tongara')))
g.add((tongara  , RDF.type, n.private_squadron_of_nainki))
g.add((tongara  , alias, Literal('Tongara')))

g.add((noria  , name, Literal('Noria')))
g.add((noria  , RDF.type, n.private_squadron_of_nainki))
g.add((noria  , alias, Literal('Noria')))

g.add((asami  , name, Literal('Asami')))
g.add((asami  , RDF.type, n.private_squadron_of_nainki))
g.add((asami  , alias, Literal('Asami')))

g.add((chinpi  , name, Literal('Chinpi')))
g.add((chinpi  , RDF.type, n.private_squadron_of_nainki))
g.add((chinpi  , alias, Literal('Chinpi')))

# %% [markdown]
# ### Agregando clase Otros

# %%
### Otros

g.add((drKuseno , name, Literal('Dr. Stench')))
g.add((drKuseno , RDF.type, n.others))
g.add((drKuseno , alias, Literal('Dr. Stench')))

g.add((shibawa , name, Literal('Shibabawa')))
g.add((shibawa , RDF.type, n.others))
g.add((shibawa , alias, Literal('Shibabawa')))

g.add((niñoBarbilla , name, Literal('Niño de la barbilla partida')))
g.add((niñoBarbilla , RDF.type, n.others))
g.add((niñoBarbilla , alias, Literal('Niño de la barbilla partida')))

g.add((anunciador , name, Literal('Anunciador de Súper Lucha')))
g.add((anunciador , RDF.type, n.others))
g.add((anunciador , alias, Literal('Anunciador de Súper Lucha')))

g.add((tacchan , name, Literal('Tacchan')))
g.add((tacchan , RDF.type, n.others))
g.add((tacchan , edad, Literal(18)))
g.add((tacchan , alias, Literal('Tacchan')))

g.add((tareo , name, Literal('Tareo')))
g.add((tareo , RDF.type, n.others))
g.add((tareo , alias, Literal('Tareo')))

g.add((waganma , name, Literal('Waganma')))
g.add((waganma , RDF.type, n.others))
g.add((waganma , alias, Literal('Waganma')))

g.add((zeniru , name, Literal('Zeniru')))
g.add((zeniru , RDF.type, n.others))
g.add((zeniru , alias, Literal('Zeniru')))

g.add((zenko , name, Literal('Zenko')))
g.add((zenko , RDF.type, n.others))
g.add((zenko , alias, Literal('Zenko')))

#print(g.serialize(format='xml').decode('utf8'))

# %% [markdown]
# ### Inferencias

# %% [markdown]
# Primera inferencia: Consultar si ex_heros es una subclase de heroes

# %%
for s in g.transitive_objects(heroes, RDFS.subClassOf):
    print(g.value(s,name))
# Out:
# Heroes
# None

# %%
def isSubClassOf(subClass, superClass, graph):
    if subClass == superClass: return True
    for parentClass in graph.objects(subClass, RDFS.subClassOf):
        if isSubClassOf(parentClass, superClass, graph): return True
        else:return False

# %%
print(isSubClassOf(n.ex_heros, heroes, g))
# Out:
# True
